# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#View-Baumgartner_C-N.pb-file" data-toc-modified-id="View-Baumgartner_C-N.pb-file-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>View Baumgartner_C-N.pb file</a></span></li><li><span><a href="#Train-ML-model-on-Baumgartner_C-N" data-toc-modified-id="Train-ML-model-on-Baumgartner_C-N-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Train ML model on Baumgartner_C-N</a></span><ul class="toc-item"><li><span><a href="#Create-datasets" data-toc-modified-id="Create-datasets-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Create datasets</a></span></li><li><span><a href="#Set-up-model-using-Tensorflow" data-toc-modified-id="Set-up-model-using-Tensorflow-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Set up model using Tensorflow</a></span></li></ul></li><li><span><a href="#Train-Benchmarks" data-toc-modified-id="Train-Benchmarks-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Train Benchmarks</a></span><ul class="toc-item"><li><span><a href="#Baumgartner_C-N" data-toc-modified-id="Baumgartner_C-N-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Baumgartner_C-N</a></span><ul class="toc-item"><li><span><a href="#Set-up-domain" data-toc-modified-id="Set-up-domain-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Set up domain</a></span></li><li><span><a href="#Create-Dataset" data-toc-modified-id="Create-Dataset-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Create Dataset</a></span></li><li><span><a href="#Save-and-load-the-benchmark" data-toc-modified-id="Save-and-load-the-benchmark-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Save and load the benchmark</a></span></li></ul></li><li><span><a href="#Ahneman" data-toc-modified-id="Ahneman-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Ahneman</a></span><ul class="toc-item"><li><span><a href="#Set-up-domain" data-toc-modified-id="Set-up-domain-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Set up domain</a></span></li><li><span><a href="#Create-Dataset" data-toc-modified-id="Create-Dataset-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Create Dataset</a></span></li><li><span><a href="#Define-pretraining-Dataset" data-toc-modified-id="Define-pretraining-Dataset-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Define pretraining Dataset</a></span></li></ul></li><li><span><a href="#Buitrago-Santinilla" data-toc-modified-id="Buitrago-Santinilla-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Buitrago-Santinilla</a></span><ul class="toc-item"><li><span><a href="#Define-pretraining-Dataset" data-toc-modified-id="Define-pretraining-Dataset-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Define pretraining Dataset</a></span></li></ul></li></ul></li><li><span><a href="#Optimisation" data-toc-modified-id="Optimisation-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Optimisation</a></span><ul class="toc-item"><li><span><a href="#Learning-how-the-Random-strategy-works" data-toc-modified-id="Learning-how-the-Random-strategy-works-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Learning how the Random strategy works</a></span></li><li><span><a href="#Run-strategies" data-toc-modified-id="Run-strategies-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Run strategies</a></span></li><li><span><a href="#multitask-BO" data-toc-modified-id="multitask-BO-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>multitask BO</a></span></li><li><span><a href="#Plot-results" data-toc-modified-id="Plot-results-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Plot results</a></span></li></ul></li><li><span><a href="#Implementing-Gaussian-process-by-hand" data-toc-modified-id="Implementing-Gaussian-process-by-hand-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Implementing Gaussian process by hand</a></span></li></ul></div>

# %% [markdown]
# # Imports

# %%
# Import modules
import ord_schema
from ord_schema import message_helpers, validations
from ord_schema.proto import dataset_pb2

import math
import pandas as pd
import numpy as np
# import tensorflow as tf
import matplotlib.pyplot as plt
import os
#import wget

from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn import model_selection, metrics
from glob import glob
from IPython.display import clear_output

#summit
import summit
from summit.benchmarks import ExperimentalEmulator
from summit.domain import *
from summit.utils.dataset import DataSet
from summit import Runner
from summit.strategies import Random, SOBO, MultitoSingleObjective, STBO, MTBO
from summit.benchmarks import SnarBenchmark
import pkg_resources
import pathlib

#implement GP by hand
import scipy

# %% [markdown]
# # View Baumgartner_C-N.pb file

# %%
pb = '../data/baumgartner_C-N/baumgartner_C-N.pb'

# Load Dataset message
data = message_helpers.load_message(pb, dataset_pb2.Dataset)

# Ensure dataset validates
valid_output = validations.validate_message(data)

# Convert dataset to pandas dataframe
df = message_helpers.messages_to_dataframe(data.reactions, 
                                           drop_constant_columns=True)

# View dataframe
df
# Out:
#      inputs["Electrophile"].components[0].amount.moles.value  \
# 0                                            13.658169
# 1                                            13.658169
# 2                                            13.658169
# 3                                            13.658169
# 4                                            13.658169
# ..                                                 ...
# 369                                          13.686801
# 370                                          13.686801
# 371                                          13.686801
# 372                                          13.686801
# 373                                          13.686801
#
#      inputs["Electrophile"].components[1].amount.mass.value  \
# 0                                           157.130951
# 1                                           157.130951
# 2                                           157.130951
# 3                                           157.130951
# 4                                           157.130951
# ..                                                 ...
# 369                                         156.398926
# 370                                         156.398926
# 371                                         156.398926
# 372                                         156.398926
# 373                                         156.398926
#
#     inputs["Electrophile"].components[2].identifiers[0].value  \
# 0                                              2-MeTHF
# 1                                              2-MeTHF
# 2                                              2-MeTHF
# 3                                              2-MeTHF
# 4                                              2-MeTHF
# ..                                                 ...
# 369                                            2-MeTHF
# 370                                            2-MeTHF
# 371                                            2-MeTHF
# 372                                            2-MeTHF
# 373                                            2-MeTHF
#
#     inputs["Electrophile"].components[2].identifiers[1].value  \
# 0                                           O1C(C)CCC1
# 1                                           O1C(C)CCC1
# 2                                           O1C(C)CCC1
# 3                                           O1C(C)CCC1
# 4                                           O1C(C)CCC1
# ..                                                 ...
# 369                                         O1C(C)CCC1
# 370                                         O1C(C)CCC1
# 371                                         O1C(C)CCC1
# 372                                         O1C(C)CCC1
# 373                                         O1C(C)CCC1
#
#      inputs["Electrophile"].components[2].amount.volume.value  \
# 0                                             3.522421
# 1                                             3.522421
# 2                                             3.522421
# 3                                             3.522421
# 4                                             3.522421
# ..                                                 ...
# 369                                           4.005343
# 370                                           4.005343
# 371                                           4.005343
# 372                                           4.005343
# 373                                           4.005343
#
#     inputs["Solvent"].components[0].identifiers[0].value  \
# 0                                              2-MeTHF
# 1                                              2-MeTHF
# 2                                              2-MeTHF
# 3                                              2-MeTHF
# 4                                              2-MeTHF
# ..                                                 ...
# 369                                            2-MeTHF
# 370                                            2-MeTHF
# 371                                            2-MeTHF
# 372                                            2-MeTHF
# 373                                            2-MeTHF
#
#     inputs["Solvent"].components[0].identifiers[1].value  \
# 0                                           O1C(C)CCC1
# 1                                           O1C(C)CCC1
# 2                                           O1C(C)CCC1
# 3                                           O1C(C)CCC1
# 4                                           O1C(C)CCC1
# ..                                                 ...
# 369                                         O1C(C)CCC1
# 370                                         O1C(C)CCC1
# 371                                         O1C(C)CCC1
# 372                                         O1C(C)CCC1
# 373                                         O1C(C)CCC1
#
#      inputs["Solvent"].components[0].amount.volume.value  \
# 0                                             2.277579
# 1                                             5.877579
# 2                                             4.210913
# 3                                             7.810913
# 4                                             6.810913
# ..                                                 ...
# 369                                           5.331594
# 370                                           7.640302
# 371                                           5.198260
# 372                                           2.152615
# 373                                           7.573636
#
#     inputs["Base"].components[0].identifiers[0].value  \
# 0                                                BTMG
# 1                                                 DBU
# 2                                                 DBU
# 3                                                 TEA
# 4                                                BTMG
# ..                                                ...
# 369                                               TEA
# 370                                              MTBD
# 371                                               DBU
# 372                                              MTBD
# 373                                               DBU
#
#     inputs["Base"].components[0].identifiers[1].value  ...  \
# 0                             CC(C)(C)N=C(N(C)C)N(C)C  ...
# 1                                    C1CCC2=NCCCN2CC1  ...
# 2                                    C1CCC2=NCCCN2CC1  ...
# 3                                           CCN(CC)CC  ...
# 4                             CC(C)(C)N=C(N(C)C)N(C)C  ...
# ..                                                ...  ...
# 369                                         CCN(CC)CC  ...
# 370                                  CN1CCCN2C1=NCCC2  ...
# 371                                  C1CCC2=NCCCN2CC1  ...
# 372                                  CN1CCCN2C1=NCCC2  ...
# 373                                  C1CCC2=NCCCN2CC1  ...
#
#      workups[0].input.components[0].identifiers[0].value  \
# 0                                              2-MeTHF
# 1                                              2-MeTHF
# 2                                              2-MeTHF
# 3                                              2-MeTHF
# 4                                              2-MeTHF
# ..                                                 ...
# 369                                            2-MeTHF
# 370                                            2-MeTHF
# 371                                            2-MeTHF
# 372                                            2-MeTHF
# 373                                            2-MeTHF
#
#     workups[0].input.components[0].identifiers[1].value  \
# 0                                           O1C(C)CCC1
# 1                                           O1C(C)CCC1
# 2                                           O1C(C)CCC1
# 3                                           O1C(C)CCC1
# 4                                           O1C(C)CCC1
# ..                                                 ...
# 369                                         O1C(C)CCC1
# 370                                         O1C(C)CCC1
# 371                                         O1C(C)CCC1
# 372                                         O1C(C)CCC1
# 373                                         O1C(C)CCC1
#
#     workups[0].input.components[0].amount.volume.value  \
# 0                                                 15.0
# 1                                                 15.0
# 2                                                 15.0
# 3                                                 15.0
# 4                                                 15.0
# ..                                                 ...
# 369                                               15.0
# 370                                               15.0
# 371                                               15.0
# 372                                               15.0
# 373                                               15.0
#
#      workups[0].amount.volume.value outcomes[0].reaction_time.value  \
# 0                              30.0                     1324.577759
# 1                              30.0                      374.843445
# 2                              30.0                     1296.335205
# 3                              30.0                      595.096008
# 4                              30.0                     1346.552979
# ..                              ...                             ...
# 369                            30.0                       73.882225
# 370                            30.0                       76.790390
# 371                            30.0                     1294.963013
# 372                            30.0                       81.582664
# 373                            30.0                       97.631584
#
#     outcomes[0].products[0].identifiers[0].value  \
# 0                       4-methyl-N-phenylaniline
# 1                       4-methyl-N-phenylaniline
# 2                       4-methyl-N-phenylaniline
# 3                       4-methyl-N-phenylaniline
# 4                       4-methyl-N-phenylaniline
# ..                                           ...
# 369                        4-(p-tolyl)morpholine
# 370                        4-(p-tolyl)morpholine
# 371                        4-(p-tolyl)morpholine
# 372                        4-(p-tolyl)morpholine
# 373                        4-(p-tolyl)morpholine
#
#      outcomes[0].products[0].identifiers[1].value  \
# 0                      CC1=CC=C(C=C1)NC2=CC=CC=C2
# 1                      CC1=CC=C(C=C1)NC2=CC=CC=C2
# 2                      CC1=CC=C(C=C1)NC2=CC=CC=C2
# 3                      CC1=CC=C(C=C1)NC2=CC=CC=C2
# 4                      CC1=CC=C(C=C1)NC2=CC=CC=C2
# ..                                            ...
# 369                        CC1=CC=C(C=C1)N2CCOCC2
# 370                        CC1=CC=C(C=C1)N2CCOCC2
# 371                        CC1=CC=C(C=C1)N2CCOCC2
# 372                        CC1=CC=C(C=C1)N2CCOCC2
# 373                        CC1=CC=C(C=C1)N2CCOCC2
#
#     outcomes[0].products[0].measurements[0].authentic_standard.identifiers[0].value  \
# 0                             4-methyl-N-phenylaniline
# 1                             4-methyl-N-phenylaniline
# 2                             4-methyl-N-phenylaniline
# 3                             4-methyl-N-phenylaniline
# 4                             4-methyl-N-phenylaniline
# ..                                                 ...
# 369                              4-(p-tolyl)morpholine
# 370                              4-(p-tolyl)morpholine
# 371                              4-(p-tolyl)morpholine
# 372                              4-(p-tolyl)morpholine
# 373                              4-(p-tolyl)morpholine
#
#     outcomes[0].products[0].measurements[0].authentic_standard.identifiers[1].value  \
# 0                           CC1=CC=C(C=C1)NC2=CC=CC=C2
# 1                           CC1=CC=C(C=C1)NC2=CC=CC=C2
# 2                           CC1=CC=C(C=C1)NC2=CC=CC=C2
# 3                           CC1=CC=C(C=C1)NC2=CC=CC=C2
# 4                           CC1=CC=C(C=C1)NC2=CC=CC=C2
# ..                                                 ...
# 369                             CC1=CC=C(C=C1)N2CCOCC2
# 370                             CC1=CC=C(C=C1)N2CCOCC2
# 371                             CC1=CC=C(C=C1)N2CCOCC2
# 372                             CC1=CC=C(C=C1)N2CCOCC2
# 373                             CC1=CC=C(C=C1)N2CCOCC2
#
#      outcomes[0].products[0].measurements[0].percentage.value
# 0                                            61.873035
# 1                                             1.446805
# 2                                            21.348686
# 3                                             0.274913
# 4                                            54.948227
# ..                                                 ...
# 369                                           0.100000
# 370                                           0.100000
# 371                                           5.087716
# 372                                           0.100000
# 373                                           4.671374
#
# [374 rows x 37 columns]

# %%
# Check for NaN values
print(f'number of NaN values: {df.isnull().sum().sum()}')

# Show column counts
df.info()
# Out:
# number of NaN values: 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 37 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   inputs["Electrophile"].components[0].amount.moles.value                          374 non-null    float64
#  1   inputs["Electrophile"].components[1].amount.mass.value                           374 non-null    float64
#  2   inputs["Electrophile"].components[2].identifiers[0].value                        374 non-null    object
#  3   inputs["Electrophile"].components[2].identifiers[1].value                        374 non-null    object
#  4   inputs["Electrophile"].components[2].amount.volume.value                         374 non-null    float64
#  5   inputs["Solvent"].components[0].identifiers[0].value                             374 non-null    object
#  6   inputs["Solvent"].components[0].identifiers[1].value                             374 non-null    object
#  7   inputs["Solvent"].components[0].amount.volume.value                              374 non-null    float64
#  8   inputs["Base"].components[0].identifiers[0].value                                374 non-null    object
#  9   inputs["Base"].components[0].identifiers[1].value                                374 non-null    object
#  10  inputs["Base"].components[0].amount.moles.value                                  374 non-null    float64
#  11  inputs["Base"].components[1].identifiers[0].value                                374 non-null    object
#  12  inputs["Base"].components[1].identifiers[1].value                                374 non-null    object
#  13  inputs["Base"].components[1].amount.volume.value                                 374 non-null    float64
#  14  inputs["Nucleophile"].components[0].identifiers[0].value                         374 non-null    object
#  15  inputs["Nucleophile"].components[0].identifiers[1].value                         374 non-null    object
#  16  inputs["Nucleophile"].components[0].amount.moles.value                           374 non-null    float64
#  17  inputs["Nucleophile"].components[1].identifiers[0].value                         374 non-null    object
#  18  inputs["Nucleophile"].components[1].identifiers[1].value                         374 non-null    object
#  19  inputs["Nucleophile"].components[1].amount.volume.value                          374 non-null    float64
#  20  inputs["Quench"].components[0].identifiers[0].value                              374 non-null    object
#  21  inputs["Quench"].components[0].identifiers[1].value                              374 non-null    object
#  22  inputs["Quench"].components[0].amount.volume.value                               374 non-null    float64
#  23  inputs["Catalyst"].components[0].identifiers[0].value                            374 non-null    object
#  24  inputs["Catalyst"].components[0].identifiers[1].value                            374 non-null    object
#  25  inputs["Catalyst"].components[0].amount.moles.value                              374 non-null    float64
#  26  conditions.temperature.setpoint.value                                            374 non-null    float64
#  27  workups[0].input.components[0].identifiers[0].value                              374 non-null    object
#  28  workups[0].input.components[0].identifiers[1].value                              374 non-null    object
#  29  workups[0].input.components[0].amount.volume.value                               374 non-null    float64
#  30  workups[0].amount.volume.value                                                   374 non-null    float64
#  31  outcomes[0].reaction_time.value                                                  374 non-null    float64
#  32  outcomes[0].products[0].identifiers[0].value                                     374 non-null    object
#  33  outcomes[0].products[0].identifiers[1].value                                     374 non-null    object
#  34  outcomes[0].products[0].measurements[0].authentic_standard.identifiers[0].value  374 non-null    object
#  35  outcomes[0].products[0].measurements[0].authentic_standard.identifiers[1].value  374 non-null    object
#  36  outcomes[0].products[0].measurements[0].percentage.value                         374 non-null    float64
# dtypes: float64(15), object(22)
# memory usage: 108.2+ KB

# %%
# Create new dataframe containing only columns to be used in modeling
model_cols = ['inputs["Catalyst"].components[0].identifiers[0].value',
              'inputs["Base"].components[0].identifiers[0].value',
              'inputs["Solvent"].components[0].identifiers[0].value',
              'inputs["Nucleophile"].components[0].identifiers[0].value',
              'outcomes[0].reaction_time.value',
              'conditions.temperature.setpoint.value',
              'outcomes[0].products[0].measurements[0].percentage.value',
             ]
df = df[model_cols]
df
# Out:
#     inputs["Catalyst"].components[0].identifiers[0].value  \
# 0                        cycloPd EPhos 4-Chlorotoluene
# 1                        cycloPd EPhos 4-Chlorotoluene
# 2                        cycloPd EPhos 4-Chlorotoluene
# 3                        cycloPd EPhos 4-Chlorotoluene
# 4                        cycloPd EPhos 4-Chlorotoluene
# ..                                                 ...
# 369               cycloPd tBuBrettPhos 4-Chlorotoluene
# 370               cycloPd tBuBrettPhos 4-Chlorotoluene
# 371               cycloPd tBuBrettPhos 4-Chlorotoluene
# 372               cycloPd tBuBrettPhos 4-Chlorotoluene
# 373               cycloPd tBuBrettPhos 4-Chlorotoluene
#
#     inputs["Base"].components[0].identifiers[0].value  \
# 0                                                BTMG
# 1                                                 DBU
# 2                                                 DBU
# 3                                                 TEA
# 4                                                BTMG
# ..                                                ...
# 369                                               TEA
# 370                                              MTBD
# 371                                               DBU
# 372                                              MTBD
# 373                                               DBU
#
#     inputs["Solvent"].components[0].identifiers[0].value  \
# 0                                              2-MeTHF
# 1                                              2-MeTHF
# 2                                              2-MeTHF
# 3                                              2-MeTHF
# 4                                              2-MeTHF
# ..                                                 ...
# 369                                            2-MeTHF
# 370                                            2-MeTHF
# 371                                            2-MeTHF
# 372                                            2-MeTHF
# 373                                            2-MeTHF
#
#     inputs["Nucleophile"].components[0].identifiers[0].value  \
# 0                                              Aniline
# 1                                              Aniline
# 2                                              Aniline
# 3                                              Aniline
# 4                                              Aniline
# ..                                                 ...
# 369                                         Morpholine
# 370                                         Morpholine
# 371                                         Morpholine
# 372                                         Morpholine
# 373                                         Morpholine
#
#      outcomes[0].reaction_time.value  conditions.temperature.setpoint.value  \
# 0                        1324.577759                                   65.0
# 1                         374.843445                                   65.0
# 2                        1296.335205                                  100.0
# 3                         595.096008                                   30.0
# 4                        1346.552979                                   65.0
# ..                               ...                                    ...
# 369                        73.882225                                   30.0
# 370                        76.790390                                   30.0
# 371                      1294.963013                                   30.0
# 372                        81.582664                                  100.0
# 373                        97.631584                                  100.0
#
#      outcomes[0].products[0].measurements[0].percentage.value
# 0                                            61.873035
# 1                                             1.446805
# 2                                            21.348686
# 3                                             0.274913
# 4                                            54.948227
# ..                                                 ...
# 369                                           0.100000
# 370                                           0.100000
# 371                                           5.087716
# 372                                           0.100000
# 373                                           4.671374
#
# [374 rows x 7 columns]

# %% [markdown]
# # Train ML model on Baumgartner_C-N

# %% [markdown]
# Following example 'Granda_Perera_ml_example' from ORD example

# %%
# Show dataset statistics for numerical fields
df.describe()

# %%
# Convert reaction input labels to one-hot encoding
input_cols = model_cols[:-1]

# Assign names for each input
prefix = ['catalyst',
          'base',
          'solvent',
          'nucleophile'
]

# Create one-hot encoded input dataset
ohe_df = pd.get_dummies(df[input_cols], prefix=prefix)

# Add yield column to ohe dataset
ohe_df['yield'] = df[model_cols[-1]]/100

# View dataset
ohe_df

# %% [markdown]
# ## Create datasets

# %%
# Create numpy arrays for inputs and outputs 
X = ohe_df.drop(columns=['yield']).values
y = ohe_df['yield'].values

# Verify array shapes
print(X.shape, y.shape)

# %%
# Set training, validation, and test sets with random_state for reproducibility
_X_train, X_test, _y_train, y_test = model_selection.train_test_split(
    X, y, test_size=0.3, random_state=0)
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(
    _X_train, _y_train, test_size=(0.1/0.7), shuffle=False)

# Check lengths
print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)
print(len(ohe_df) == X_train.shape[0] + X_valid.shape[0] + X_test.shape[0])

# %%
# Create training, validation, and test sets as tf Datasets and batch
batch_size = 100
train_dataset = tf.data.Dataset.from_tensor_slices(
    (X_train, y_train)).batch(batch_size)
valid_dataset = tf.data.Dataset.from_tensor_slices(
    (X_valid, y_valid)).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (X_test, y_test)).batch(batch_size)

# Check length (in batches)
print(train_dataset.cardinality().numpy())
print(valid_dataset.cardinality().numpy())
print(test_dataset.cardinality().numpy())

# %% [markdown]
# ## Set up model using Tensorflow
# Using hyperparameters from Granda et al. Nature 2018, 559, 377, DOI: 10.1038/s41586-018-0307-8.

# %%
# Set model parameters
epochs = 300

# Construct model
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=X_train.shape[1]),
    tf.keras.layers.Dense(50, activation='sigmoid'),
    tf.keras.layers.Dense(7, activation='sigmoid'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1),
])

# Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(0.005),
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Setup callback to load weights from best epoch later on
# Saving model weights from epoch with lowest validation loss
checkpoint_filepath = os.path.join(os.getcwd(), 'saved_model')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

# Train model
history = model.fit(train_dataset,
                    epochs=epochs,
                    callbacks=[model_checkpoint_callback],
                    validation_data=valid_dataset)

# %%
# Show best epoch
best_epoch = np.argmin(np.array(history.history['val_loss']))
best_epoch

# %%
# Load model weights from best epoch
model.load_weights(os.path.join(checkpoint_filepath, 'variables/variables'))

# Generate predictions for test set and measure test RMSE and R2
preds = model.predict(test_dataset)
evals = model.evaluate(x=test_dataset, return_dict=True)
r2 = metrics.r2_score(y_test, preds)
rmse = evals['root_mean_squared_error']
print(f'Test RMSE: {evals}')
print(f'Test R2: {r2}')

# Plot model performance
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18,6))
fig.suptitle('Baumgartner C-N HTE MLP Model Performance')

# Plot loss through training
ax1.plot(history.history['loss'], 'b', label='training loss')
ax1.plot(history.history['val_loss'], 'g', label='validation loss')
ax1.legend()
ax1.set_ylabel('loss (MSE)')
ax1.set_xlabel('epoch')
ax1.set_title('loss curves')

# Plot predictions vs ground truth
ax2.plot(y_test, preds, 'bo')
ax2.plot([0, 1], 'r')
ax2.set_ylabel('predicted yield')
ax2.set_xlabel('ground truth yield')
ax2.set_title('predictions vs ground truth')
ax2.text(0.6, 0, f'test_RMSE: {round(rmse, 3)}')
ax2.text(0.6, -0.05, f'test_R2: {round(r2, 3)}')

# View performance plots
plt.show()

# %%
# Show ground truth and predicted yield distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))
fig.suptitle('Ground Truth and Predicted Yield Distributions')

# Plot ground truth histogram
ax1.hist(ohe_df['yield'], bins=20, rwidth=0.93, color='navy')
ax1.set_title('ground truth')
ax1.set_xlabel('yield')
ax1.set_ylabel('frequency (count)')

# Plot predicted histogram
ax2.hist(preds, bins=20, rwidth=0.93, color='navy')
ax2.set_title('predictions')
ax2.set_xlabel('yield')
ax2.set_ylabel('frequency (count)')

# View distributions
plt.show()

# %% [markdown]
# # Train Benchmarks
# https://gosummit.readthedocs.io/en/latest/tutorials/new_benchmarks.html

# %% [markdown]
# ## Baumgartner_C-N

# %% [markdown]
# ### Set up domain

# %% [markdown]
# We are going to manipulate:
# - Ligand (precatalyst is always the same)
# - Nucleophile
# - Base
# - Solvent
# - Temperature
# - Reaction time
#
# Objective: Maximise yield

# %%
domain = Domain()

# Decision variables
# The precatalyst is always the same: https://www.strem.com/catalog/v/46-0308/51/palladium_225931-80-6
# The additive is always the same: 4-Chlorotoluene
# The ligand changes

des_1 = "Catalyst"
domain += CategoricalVariable(
    name='inputs["Catalyst"].components[0].identifiers[0].value',
    description=des_1,
    levels=[
        'cycloPd tBuXPhos 4-Chlorotoluene', 
         'cycloPd EPhos 4-Chlorotoluene', 
         'cycloPd AlPhos 4-Chlorotoluene', 
         'cycloPd tBuBrettPhos 4-Chlorotoluene',
    ],
)

# Decision variables
des_2 = "Nucleophile"
domain += CategoricalVariable(
    name='inputs["Nucleophile"].components[0].identifiers[0].value',
    description=des_2,
    levels=[
        "Aniline",
        "Benzamide",
        "Phenethylamine",
        "Morpholine",
    ],
)

# Decision variables
des_3 = "Base"
domain += CategoricalVariable(
    name='inputs["Base"].components[0].identifiers[0].value',
    description=des_3,
    levels=[
        "TEA",
        "Triethylamine",
        "TMG",
        "BTMG",
        "DBU",
        "MTBD",
        "BTTP",
        "P2Et",
    ],
)

# Decision variables
des_4 = "Solvent"
domain += CategoricalVariable(
    name='inputs["Solvent"].components[0].identifiers[0].value',
    description=des_4,
    levels=[
        "2-MeTHF",
        "DMSO",
    ],
)

des_5 = "Residence time in seconds (s)"
domain += ContinuousVariable(name="outcomes[0].reaction_time.value", description=des_5, bounds=[60, 6000])

des_6 = "Reactor temperature in degrees Celsius (ºC)"
domain += ContinuousVariable(
    name="conditions.temperature.setpoint.value", description=des_6, bounds=[30, 110]
)


# Objectives
des_7 = "Yield"
domain += ContinuousVariable(
    name="outcomes[0].products[0].measurements[0].percentage.value",
    description=des_5,
    bounds=[0, 105],
    is_objective=True,
    maximize=True,
)

# %%
domain
# Out:
# <table id='domain' width=100%><tr><td><b>Name</b></td><td><b>Type</b></td><td><b>Description</b></td><td><b>Values</b></td></tr><tr><td>inputs["Catalyst"].components[0].identifiers[0].value</td><td>categorical, input</td><td>Catalyst</td><td>4 levels</td></tr><tr><td>inputs["Nucleophile"].components[0].identifiers[0].value</td><td>categorical, input</td><td>Nucleophile</td><td>4 levels</td></tr><tr><td>inputs["Base"].components[0].identifiers[0].value</td><td>categorical, input</td><td>Base</td><td>8 levels</td></tr><tr><td>inputs["Solvent"].components[0].identifiers[0].value</td><td>categorical, input</td><td>Solvent</td><td>2 levels</td></tr><tr><td>outcomes[0].reaction_time.value</td><td>continuous, input</td><td>Residence time in seconds (s)</td><td>[60,6000]</td></tr><tr><td>conditions.temperature.setpoint.value</td><td>continuous, input</td><td>Reactor temperature in degrees Celsius (ºC)</td><td>[30,110]</td></tr><tr><td>outcomes[0].products[0].measurements[0].percentage.value</td><td>continuous, maximize objective</td><td>Residence time in seconds (s)</td><td>[0,105]</td></tr></table>

# %% [markdown]
# ### Create Dataset

# %%
# shuffle df
df_shuffle = df.sample(frac=1)
baumgartner_cn_ds = DataSet.from_df(df_shuffle)

# %%
# train benchmark
baumgartner_cn = ExperimentalEmulator(model_name='baumgartner_cn', domain=domain, dataset=baumgartner_cn_ds)
baumgartner_cn.train(max_epochs=1000, cv_fold=2, test_size=0.1, verbose=1)

#Parity plot
fig, ax = baumgartner_cn.parity_plot(include_test=True)

# %%
#Test out a set of conditions on the benchmark
conditions = [["cycloPd EPhos 4-Chlorotoluene",'Aniline', 'BTMG', '2-MeTHF', 1324, 65.0]]
conditions = DataSet(conditions, columns=[v.name for v in domain.input_variables])
baumgartner_cn.run_experiments(conditions)

# %% [markdown]
# ### Save and load the benchmark

# %%
# Save it
baumgartner_cn.save(save_dir="/Users/dsw46/OneDrive - University of Cambridge/Cambridge\
/Projects/multitask/multitask/data/baumgartner_C-N/baumgartner_C-N_emulator")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-58f9a4039b24> in <module>
#       1 # Save it
# ----> 2 baumgartner_cn.save(save_dir="/Users/dsw46/OneDrive - University of Cambridge/Cambridge\
#       3 /Projects/multitask/multitask/data/baumgartner_C-N/baumgartner_C-N_emulator")
#
# NameError: name 'baumgartner_cn' is not defined

# %%
# Load it
baumgartner_cn = ExperimentalEmulator.load(model_name="baumgartner_cn", save_dir="../data/baumgartner_C-N/baumgartner_C-N_emulator")

# %% [markdown]
# ## Ahneman

# %%
pb = '../data/Ahneman/ord/ahneman.pb'

# Load Dataset message
data = message_helpers.load_message(pb, dataset_pb2.Dataset)

# Ensure dataset validates
valid_output = validations.validate_message(data)

# Convert dataset to pandas dataframe
ahneman_df = message_helpers.messages_to_dataframe(data.reactions, 
                                           drop_constant_columns=True)

# View dataframe
ahneman_df
# Out:
#      inputs["catalyst"].components[0].identifiers[0].value  \
# 0                                                 XPhos
# 1                                                 XPhos
# 2                                                 XPhos
# 3                                                 XPhos
# 4                                                 XPhos
# ...                                                 ...
# 4307                                        AdBrettPhos
# 4308                                        AdBrettPhos
# 4309                                        AdBrettPhos
# 4310                                        AdBrettPhos
# 4311                                        AdBrettPhos
#
#      inputs["catalyst"].components[0].identifiers[1].value  \
# 0     CC(C)c1cc(C(C)C)c(-c2ccccc2P(C2CCCCC2)(C2CCCCC...
# 1     CC(C)c1cc(C(C)C)c(-c2ccccc2P(C2CCCCC2)(C2CCCCC...
# 2     CC(C)c1cc(C(C)C)c(-c2ccccc2P(C2CCCCC2)(C2CCCCC...
# 3     CC(C)c1cc(C(C)C)c(-c2ccccc2P(C2CCCCC2)(C2CCCCC...
# 4     CC(C)c1cc(C(C)C)c(-c2ccccc2P(C2CCCCC2)(C2CCCCC...
# ...                                                 ...
# 4307  COc1ccc(OC)c(P(C23CC4CC(CC(C4)C2)C3)(C23CC4CC(...
# 4308  COc1ccc(OC)c(P(C23CC4CC(CC(C4)C2)C3)(C23CC4CC(...
# 4309  COc1ccc(OC)c(P(C23CC4CC(CC(C4)C2)C3)(C23CC4CC(...
# 4310  COc1ccc(OC)c(P(C23CC4CC(CC(C4)C2)C3)(C23CC4CC(...
# 4311  COc1ccc(OC)c(P(C23CC4CC(CC(C4)C2)C3)(C23CC4CC(...
#
#      inputs["additive"].components[0].identifiers[0].type  \
# 0                                                  NAME
# 1                                                  NAME
# 2                                                  NAME
# 3                                                  NAME
# 4                                                  NAME
# ...                                                 ...
# 4307                                             SMILES
# 4308                                             SMILES
# 4309                                             SMILES
# 4310                                             SMILES
# 4311                                             SMILES
#
#      inputs["additive"].components[0].identifiers[0].value  \
# 0                                                  DMSO
# 1                                                  DMSO
# 2                                                  DMSO
# 3                                                  DMSO
# 4                                                  DMSO
# ...                                                 ...
# 4307                           COC(=O)c1cc(-c2cccs2)on1
# 4308                           COC(=O)c1cc(-c2cccs2)on1
# 4309                           COC(=O)c1cc(-c2cccs2)on1
# 4310                           COC(=O)c1cc(-c2cccs2)on1
# 4311                           COC(=O)c1cc(-c2cccs2)on1
#
#      inputs["additive"].components[0].identifiers[1].type  \
# 0                                                SMILES
# 1                                                SMILES
# 2                                                SMILES
# 3                                                SMILES
# 4                                                SMILES
# ...                                                 ...
# 4307                                                NaN
# 4308                                                NaN
# 4309                                                NaN
# 4310                                                NaN
# 4311                                                NaN
#
#      inputs["additive"].components[0].identifiers[1].value  \
# 0                                               CS(=O)C
# 1                                               CS(=O)C
# 2                                               CS(=O)C
# 3                                               CS(=O)C
# 4                                               CS(=O)C
# ...                                                 ...
# 4307                                                NaN
# 4308                                                NaN
# 4309                                                NaN
# 4310                                                NaN
# 4311                                                NaN
#
#       inputs["additive"].components[0].amount.volume.value  \
# 0                                                   0.2
# 1                                                   0.2
# 2                                                   0.2
# 3                                                   0.2
# 4                                                   0.2
# ...                                                 ...
# 4307                                                NaN
# 4308                                                NaN
# 4309                                                NaN
# 4310                                                NaN
# 4311                                                NaN
#
#      inputs["additive"].components[0].amount.volume.units  \
# 0                                            MICROLITER
# 1                                            MICROLITER
# 2                                            MICROLITER
# 3                                            MICROLITER
# 4                                            MICROLITER
# ...                                                 ...
# 4307                                                NaN
# 4308                                                NaN
# 4309                                                NaN
# 4310                                                NaN
# 4311                                                NaN
#
#      inputs["additive"].components[0].amount.volume_includes_solutes  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 4307                                                NaN
# 4308                                                NaN
# 4309                                                NaN
# 4310                                                NaN
# 4311                                                NaN
#
#      inputs["additive"].components[0].reaction_role  ...  \
# 0                                           SOLVENT  ...
# 1                                           SOLVENT  ...
# 2                                           SOLVENT  ...
# 3                                           SOLVENT  ...
# 4                                           SOLVENT  ...
# ...                                             ...  ...
# 4307                                        REAGENT  ...
# 4308                                        REAGENT  ...
# 4309                                        REAGENT  ...
# 4310                                        REAGENT  ...
# 4311                                        REAGENT  ...
#
#      inputs["additive"].components[1].identifiers[0].type  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4307                                               NAME
# 4308                                               NAME
# 4309                                               NAME
# 4310                                               NAME
# 4311                                               NAME
#
#      inputs["additive"].components[1].identifiers[0].value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4307                                               DMSO
# 4308                                               DMSO
# 4309                                               DMSO
# 4310                                               DMSO
# 4311                                               DMSO
#
#      inputs["additive"].components[1].identifiers[1].type  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4307                                             SMILES
# 4308                                             SMILES
# 4309                                             SMILES
# 4310                                             SMILES
# 4311                                             SMILES
#
#      inputs["additive"].components[1].identifiers[1].value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4307                                            CS(=O)C
# 4308                                            CS(=O)C
# 4309                                            CS(=O)C
# 4310                                            CS(=O)C
# 4311                                            CS(=O)C
#
#      inputs["additive"].components[1].amount.volume.value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4307                                                0.2
# 4308                                                0.2
# 4309                                                0.2
# 4310                                                0.2
# 4311                                                0.2
#
#       inputs["additive"].components[1].amount.volume.units  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4307                                         MICROLITER
# 4308                                         MICROLITER
# 4309                                         MICROLITER
# 4310                                         MICROLITER
# 4311                                         MICROLITER
#
#      inputs["additive"].components[1].amount.volume_includes_solutes  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4307                                               True
# 4308                                               True
# 4309                                               True
# 4310                                               True
# 4311                                               True
#
#      inputs["additive"].components[1].reaction_role  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 4307                                        SOLVENT
# 4308                                        SOLVENT
# 4309                                        SOLVENT
# 4310                                        SOLVENT
# 4311                                        SOLVENT
#
#      inputs["additive"].components[1].preparations[0].type  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4307                                               NONE
# 4308                                               NONE
# 4309                                               NONE
# 4310                                               NONE
# 4311                                               NONE
#
#      inputs["additive"].components[1].source.vendor
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 4307                                        Aldrich
# 4308                                        Aldrich
# 4309                                        Aldrich
# 4310                                        Aldrich
# 4311                                        Aldrich
#
# [4312 rows x 32 columns]

# %%
# Check for NaN values
print(f'number of NaN values: {ahneman_df.isnull().sum().sum()}')

# Show column counts
ahneman_df.info()
# Out:
# number of NaN values: 26952
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4312 entries, 0 to 4311
# Data columns (total 32 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   inputs["catalyst"].components[0].identifiers[0].value            4312 non-null   object
#  1   inputs["catalyst"].components[0].identifiers[1].value            4312 non-null   object
#  2   inputs["additive"].components[0].identifiers[0].type             4312 non-null   object
#  3   inputs["additive"].components[0].identifiers[0].value            4312 non-null   object
#  4   inputs["additive"].components[0].identifiers[1].type             180 non-null    object
#  5   inputs["additive"].components[0].identifiers[1].value            180 non-null    object
#  6   inputs["additive"].components[0].amount.volume.value             180 non-null    float64
#  7   inputs["additive"].components[0].amount.volume.units             180 non-null    object
#  8   inputs["additive"].components[0].amount.volume_includes_solutes  180 non-null    object
#  9   inputs["additive"].components[0].reaction_role                   4312 non-null   object
#  10  inputs["additive"].components[0].source.vendor                   180 non-null    object
#  11  inputs["base"].components[0].identifiers[0].value                4312 non-null   object
#  12  inputs["base"].components[0].identifiers[1].value                4312 non-null   object
#  13  inputs["aryl halide"].components[0].identifiers[0].value         4312 non-null   object
#  14  outcomes[0].products[0].identifiers[0].value                     4312 non-null   object
#  15  outcomes[0].products[0].measurements[0].percentage.value         4312 non-null   float64
#  16  provenance.record_modified[0].time.value                         4312 non-null   object
#  17  provenance.record_modified[1].time.value                         4312 non-null   object
#  18  provenance.record_modified[2].time.value                         4312 non-null   object
#  19  reaction_id                                                      4312 non-null   object
#  20  inputs["additive"].components[0].amount.moles.value              4132 non-null   float64
#  21  inputs["additive"].components[0].amount.moles.units              4132 non-null   object
#  22  inputs["additive"].components[1].identifiers[0].type             4132 non-null   object
#  23  inputs["additive"].components[1].identifiers[0].value            4132 non-null   object
#  24  inputs["additive"].components[1].identifiers[1].type             4132 non-null   object
#  25  inputs["additive"].components[1].identifiers[1].value            4132 non-null   object
#  26  inputs["additive"].components[1].amount.volume.value             4132 non-null   float64
#  27  inputs["additive"].components[1].amount.volume.units             4132 non-null   object
#  28  inputs["additive"].components[1].amount.volume_includes_solutes  4132 non-null   object
#  29  inputs["additive"].components[1].reaction_role                   4132 non-null   object
#  30  inputs["additive"].components[1].preparations[0].type            4132 non-null   object
#  31  inputs["additive"].components[1].source.vendor                   4132 non-null   object
# dtypes: float64(4), object(28)
# memory usage: 1.1+ MB

# %%
# Create new dataframe containing only columns to be used in modeling
model_cols = ['inputs["catalyst"].components[0].identifiers[0].value',
              'inputs["base"].components[0].identifiers[0].value',
              'inputs["aryl halide"].components[0].identifiers[0].value',
              'inputs["additive"].components[0].identifiers[0].value',
              'inputs["additive"].components[1].identifiers[0].value',
              'outcomes[0].products[0].measurements[0].percentage.value',
             ]
ahneman_df = ahneman_df[model_cols]
ahneman_df
# Out:
#      inputs["catalyst"].components[0].identifiers[0].value  \
# 0                                                 XPhos
# 1                                                 XPhos
# 2                                                 XPhos
# 3                                                 XPhos
# 4                                                 XPhos
# ...                                                 ...
# 4307                                        AdBrettPhos
# 4308                                        AdBrettPhos
# 4309                                        AdBrettPhos
# 4310                                        AdBrettPhos
# 4311                                        AdBrettPhos
#
#      inputs["base"].components[0].identifiers[0].value  \
# 0                                                 P2Et
# 1                                                 P2Et
# 2                                                 P2Et
# 3                                                 P2Et
# 4                                                 P2Et
# ...                                                ...
# 4307                                              MTBD
# 4308                                              MTBD
# 4309                                              MTBD
# 4310                                              MTBD
# 4311                                              MTBD
#
#      inputs["aryl halide"].components[0].identifiers[0].value  \
# 0                                  FC(F)(F)c1ccc(Cl)cc1
# 1                                  FC(F)(F)c1ccc(Br)cc1
# 2                                   FC(F)(F)c1ccc(I)cc1
# 3                                        COc1ccc(Cl)cc1
# 4                                        COc1ccc(Br)cc1
# ...                                                 ...
# 4307                                         Brc1ccccn1
# 4308                                          Ic1ccccn1
# 4309                                         Clc1cccnc1
# 4310                                         Brc1cccnc1
# 4311                                          Ic1cccnc1
#
#      inputs["additive"].components[0].identifiers[0].value  \
# 0                                                  DMSO
# 1                                                  DMSO
# 2                                                  DMSO
# 3                                                  DMSO
# 4                                                  DMSO
# ...                                                 ...
# 4307                           COC(=O)c1cc(-c2cccs2)on1
# 4308                           COC(=O)c1cc(-c2cccs2)on1
# 4309                           COC(=O)c1cc(-c2cccs2)on1
# 4310                           COC(=O)c1cc(-c2cccs2)on1
# 4311                           COC(=O)c1cc(-c2cccs2)on1
#
#      inputs["additive"].components[1].identifiers[0].value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4307                                               DMSO
# 4308                                               DMSO
# 4309                                               DMSO
# 4310                                               DMSO
# 4311                                               DMSO
#
#       outcomes[0].products[0].measurements[0].percentage.value
# 0                                             26.888615
# 1                                             24.063225
# 2                                             47.515820
# 3                                              2.126831
# 4                                             47.586353
# ...                                                 ...
# 4307                                          57.426670
# 4308                                          86.233154
# 4309                                           1.440081
# 4310                                          43.538364
# 4311                                          69.795906
#
# [4312 rows x 6 columns]

# %%
cat = set(ahneman_df[model_cols[0]])
print('Catalysts: ',cat)
base = set(ahneman_df[model_cols[1]])
print('Bases: ',base)
aryl_halides = set(ahneman_df[model_cols[2]])
print('Aryl halides: ',aryl_halides)
solvent_0 = set(ahneman_df[model_cols[3]])
print('Solvent 0: ',solvent_0)
solvent_1 = set(ahneman_df[model_cols[4]])
print('Solvent 1: ',solvent_1)

# %%
set(df['inputs["additive"].components[0].amount.moles.value'])

# %% [markdown]
# ### Set up domain

# %%
ahneman_domain = Domain()

# Decision variables

des_1 = "Catalyst"
ahneman_domain += CategoricalVariable(
    name='inputs["Catalyst"].components[0].identifiers[0].value',
    description=des_1,
    levels=[
    'AdBrettPhos', 'XPhos', 
    't-BuBrettPhos', 't-BuXPhos',
    ],
)

# Decision variables
des_2 = "Base"
ahneman_domain += CategoricalVariable(
    name='inputs["Base"].components[0].identifiers[0].value',
    description=des_2,
    levels=[
    'P2Et', 'BTMG', 
    'MTBD',
    ],
)

# Decision variables
des_3 = "aryl_halide"
ahneman_domain += CategoricalVariable(
    name='inputs["Nucleophile"].components[0].identifiers[0].value',
    description=des_3,
    levels=[
    'FC(F)(F)c1ccc(Cl)cc1', 'FC(F)(F)c1ccc(Br)cc1', 'COc1ccc(Cl)cc1', 
    'Brc1cccnc1', 'Ic1ccccn1', 'COc1ccc(Br)cc1', 'CCc1ccc(I)cc1', 'Brc1ccccn1', 
    'Clc1ccccn1', 'Ic1cccnc1', 'Clc1cccnc1', 'COc1ccc(I)cc1', 
    'FC(F)(F)c1ccc(I)cc1', 'CCc1ccc(Br)cc1', 'CCc1ccc(Cl)cc1',
    ],
)

# Decision variables
des_4 = "Solvent_0"
ahneman_domain += CategoricalVariable(
    name='inputs["Solvent"].components[0].identifiers[0].value',
    description=des_4,
    levels=[
    'Cc1ccon1', 'Fc1cccc(F)c1-c1ccno1', 'c1ccc(-c2cnoc2)cc1',
    'CCOC(=O)c1cc(C)no1', 'c1ccc(CN(Cc2ccccc2)c2ccon2)cc1', 
    'Cc1cc(C)on1', 'CCOC(=O)c1ccon1', 'CCOC(=O)c1cnoc1C', 
    'c1ccc2nocc2c1', 'COC(=O)c1ccno1', 'CCOC(=O)c1cc(OC)no1', 
    'c1ccc(-c2ccno2)cc1', 'c1ccc(CN(Cc2ccccc2)c2ccno2)cc1',
    'c1ccc(-c2ccon2)cc1', 'Cc1cc(-c2ccccc2)on1', 
    'c1ccc2oncc2c1', 'Cc1ccno1', 'COC(=O)c1cc(-c2cccs2)on1', 
    'COC(=O)c1cc(-c2ccco2)on1', 'CCOC(=O)c1cc(C)on1', 
    'Cc1cc(-n2cccc2)no1', 'c1ccc(-c2ncno2)cc1', 
    'DMSO', 'CCOC(=O)c1cnoc1'
    ],
)

# Decision variables
des_5 = "Solvent_1"
ahneman_domain += CategoricalVariable(
    name='inputs["Solvent"].components[0].identifiers[0].value',
    description=des_5,
    levels=[
    'NaN', 'DMSO'
    ],
)


# Objectives
des_7 = "Yield"
ahneman_domain += ContinuousVariable(
    name="outcomes[0].products[0].measurements[0].percentage.value",
    description=des_5,
    bounds=[0, 100],
    is_objective=True,
    maximize=True,
)

# %% [markdown]
# ### Create Dataset

# %%
# shuffle df
df_shuffle = ahneman_df.sample(frac=1)
ahneman_cn_ds = DataSet.from_df(df_shuffle)

# %%
# train benchmark
ahneman_cn = ExperimentalEmulator(model_name='ahneman_cn', domain=ahneman_domain, dataset=ahneman_cn_ds)
ahneman_cn.train(max_epochs=1000, cv_fold=2, test_size=0.1, verbose=1)

#Parity plot
fig, ax = ahneman_cn.parity_plot(include_test=True)

# %%
#Test out a set of conditions on the benchmark
conditions = [["cycloPd EPhos 4-Chlorotoluene",'Aniline', 'BTMG', '2-MeTHF', 1324, 65.0]]
conditions = DataSet(conditions, columns=[v.name for v in domain.input_variables])
baumgartner_cn.run_experiments(conditions)

# %% [markdown]
# ### Define pretraining Dataset

# %%
# shuffle df
df_shuffle = ahneman_df.sample(frac=1)
ahneman_cn_ds = DataSet.from_df(df_shuffle)

# %% [markdown]
# ## Buitrago-Santinilla

# %%
pb = '../data/Buitrago-Santinilla/ord/Buitrago-Santinilla.pb'

# Load Dataset message
data = message_helpers.load_message(pb, dataset_pb2.Dataset)

# Ensure dataset validates
valid_output = validations.validate_message(data)

# Convert dataset to pandas dataframe
df = message_helpers.messages_to_dataframe(data.reactions, 
                                           drop_constant_columns=True)

# View dataframe
df
# Out:
#             identifiers[0].value  \
# 0     Buchwald-Hartwig amination
# 1     Buchwald-Hartwig amination
# 2     Buchwald-Hartwig amination
# 3     Buchwald-Hartwig amination
# 4     Buchwald-Hartwig amination
# ...                          ...
# 1531        Sonogashira coupling
# 1532        Sonogashira coupling
# 1533        Sonogashira coupling
# 1534        Sonogashira coupling
# 1535        Sonogashira coupling
#
#      inputs["base"].components[0].identifiers[0].value  \
# 0                                     C1CCC2=NCCCN2CC1
# 1                                     CN1CCCN2CCCN=C12
# 2                              CN(C)C(=NC(C)(C)C)N(C)C
# 3                      CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C
# 4                 CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1
# ...                                                ...
# 1531                                  CN1CCCN2CCCN=C12
# 1532                           CN(C)C(=NC(C)(C)C)N(C)C
# 1533                   CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C
# 1534              CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1
# 1535         CCN=P(N=P(N(C)C)(N(C)C)N(C)C)(N(C)C)N(C)C
#
#      inputs["base"].components[0].identifiers[1].value  \
# 0                                               DBU 24
# 1                                              MTBD 25
# 2                                              BTMG 26
# 3                                              BEMP 27
# 4                                              BTTP 28
# ...                                                ...
# 1531                                           MTBD 25
# 1532                                           BTMG 26
# 1533                                           BEMP 27
# 1534                                           BTTP 28
# 1535                                           P2Et 29
#
#      inputs["catalyst"].components[0].identifiers[0].value  \
# 0     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 1     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 2     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 3     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 4     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# ...                                                 ...
# 1531  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1532  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1533  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1534  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1535  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
#
#      inputs["catalyst"].components[0].identifiers[1].value  \
# 0                                        BINAP Pd G3 30
# 1                                        BINAP Pd G3 30
# 2                                        BINAP Pd G3 30
# 3                                        BINAP Pd G3 30
# 4                                        BINAP Pd G3 30
# ...                                                 ...
# 1531                               AdBrettPhos Pd G3 45
# 1532                               AdBrettPhos Pd G3 45
# 1533                               AdBrettPhos Pd G3 45
# 1534                               AdBrettPhos Pd G3 45
# 1535                               AdBrettPhos Pd G3 45
#
#      inputs["nucleophile"].components[0].identifiers[0].value  \
# 0                                       CC(N)CCc1ccccc1
# 1                                       CC(N)CCc1ccccc1
# 2                                       CC(N)CCc1ccccc1
# 3                                       CC(N)CCc1ccccc1
# 4                                       CC(N)CCc1ccccc1
# ...                                                 ...
# 1531                                  C#Cc1ccc(CCCC)cc1
# 1532                                  C#Cc1ccc(CCCC)cc1
# 1533                                  C#Cc1ccc(CCCC)cc1
# 1534                                  C#Cc1ccc(CCCC)cc1
# 1535                                  C#Cc1ccc(CCCC)cc1
#
#      inputs["nucleophile"].components[0].identifiers[1].value  \
# 0                                              amine S1
# 1                                              amine S1
# 2                                              amine S1
# 3                                              amine S1
# 4                                              amine S1
# ...                                                 ...
# 1531                                         alkyne S16
# 1532                                         alkyne S16
# 1533                                         alkyne S16
# 1534                                         alkyne S16
# 1535                                         alkyne S16
#
#      outcomes[0].products[0].identifiers[0].value  \
# 0                         CC(CCc1ccccc1)Nc1cccnc1
# 1                         CC(CCc1ccccc1)Nc1cccnc1
# 2                         CC(CCc1ccccc1)Nc1cccnc1
# 3                         CC(CCc1ccccc1)Nc1cccnc1
# 4                         CC(CCc1ccccc1)Nc1cccnc1
# ...                                           ...
# 1531                    CCCCc1ccc(C#Cc2cccnc2)cc1
# 1532                    CCCCc1ccc(C#Cc2cccnc2)cc1
# 1533                    CCCCc1ccc(C#Cc2cccnc2)cc1
# 1534                    CCCCc1ccc(C#Cc2cccnc2)cc1
# 1535                    CCCCc1ccc(C#Cc2cccnc2)cc1
#
#       outcomes[0].products[0].measurements[1].float_value.value  \
# 0                                          0.000000e+00
# 1                                          0.000000e+00
# 2                                          0.000000e+00
# 3                                          3.268438e+04
# 4                                          0.000000e+00
# ...                                                 ...
# 1531                                       3.046576e+06
# 1532                                       2.789535e+06
# 1533                                       4.537288e+05
# 1534                                       1.109048e+06
# 1535                                       4.682473e+05
#
#      outcomes[0].products[0].measurements[2].analysis_key  ...  \
# 0                                                  UPLC    ...
# 1                                                  UPLC    ...
# 2                                                  UPLC    ...
# 3                                                  UPLC    ...
# 4                                                  UPLC    ...
# ...                                                 ...    ...
# 1531                                               UPLC    ...
# 1532                                               UPLC    ...
# 1533                                               UPLC    ...
# 1534                                               UPLC    ...
# 1535                                               UPLC    ...
#
#      provenance.record_modified[2].time.value  \
# 0                  2021-03-04 14:08:27.746479
# 1                  2021-03-04 14:08:27.757195
# 2                  2021-03-04 14:08:27.767941
# 3                  2021-03-04 14:08:27.777925
# 4                  2021-03-04 14:08:27.789616
# ...                                       ...
# 1531               2021-03-04 14:08:45.263375
# 1532               2021-03-04 14:08:45.272684
# 1533               2021-03-04 14:08:45.282510
# 1534               2021-03-04 14:08:45.291804
# 1535               2021-03-04 14:08:45.301258
#
#                                reaction_id  \
# 0     ord-62a27aab55d94574b2b57fcdf70bc856
# 1     ord-114610bcc8ba4eb9b09fec460cd63226
# 2     ord-05e49b63873c4286a70e207fdda55ac1
# 3     ord-4c0bfb1703ca4be8a78075d4a804d13f
# 4     ord-3737da5147cb48b28725c90c3d98d9c1
# ...                                    ...
# 1531  ord-643348c47c0d4f98aed8a711939d2302
# 1532  ord-bd86d2743ef4430e815c6783a01a7610
# 1533  ord-91c8ce372fd84bf2b2fc30935d9f7ac5
# 1534  ord-819dbbd6d2dd4b43ba94775faf98542d
# 1535  ord-3079363eae05406cb2fe76b065fc4d45
#
#      inputs["nucleophile"].components[2].identifiers[0].type  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
# 1535                                                NaN
#
#      inputs["nucleophile"].components[2].identifiers[0].value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
# 1535                                                NaN
#
#       inputs["nucleophile"].components[2].identifiers[1].type  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
# 1535                                                NaN
#
#       inputs["nucleophile"].components[2].identifiers[1].value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
# 1535                                                NaN
#
#      inputs["nucleophile"].components[2].amount.moles.value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
# 1535                                                NaN
#
#      inputs["nucleophile"].components[2].amount.moles.units  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
# 1535                                                NaN
#
#      inputs["nucleophile"].components[2].reaction_role  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1531                                               NaN
# 1532                                               NaN
# 1533                                               NaN
# 1534                                               NaN
# 1535                                               NaN
#
#      inputs["nucleophile"].components[2].is_limiting
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 1531                                             NaN
# 1532                                             NaN
# 1533                                             NaN
# 1534                                             NaN
# 1535                                             NaN
#
# [1536 rows x 45 columns]

# %%
df.describe()
# Out:
#        outcomes[0].products[0].measurements[1].float_value.value  \
# count                                       1.536000e+03
# mean                                        4.282438e+05
# std                                         9.515332e+05
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.587670e+05
# max                                         6.411983e+06
#
#        outcomes[0].products[0].measurements[2].float_value.value  \
# count                                        1531.000000
# mean                                            2.057352
# std                                             4.755104
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.159855
# max                                            39.811352
#
#        outcomes[0].products[1].measurements[1].float_value.value  \
# count                                       1.536000e+03
# mean                                        8.901066e+05
# std                                         3.836603e+05
# min                                         0.000000e+00
# 25%                                         7.479278e+05
# 50%                                         1.023685e+06
# 75%                                         1.126468e+06
# max                                         2.181530e+06
#
#        outcomes[0].products[1].measurements[2].float_value.value  \
# count                                        1531.000000
# mean                                            4.187791
# std                                             2.507223
# min                                             0.000000
# 25%                                             2.754501
# 50%                                             4.526303
# 75%                                             5.462972
# max                                            30.952465
#
#        outcomes[0].products[2].measurements[1].float_value.value  \
# count                                       1.536000e+03
# mean                                        9.006787e+05
# std                                         1.137724e+06
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.093107e+06
# max                                         5.094170e+06
#
#        outcomes[0].products[2].measurements[2].float_value.value  \
# count                                        1531.000000
# mean                                            3.675874
# std                                             4.784036
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             8.580604
# max                                            28.707903
#
#        outcomes[0].products[3].measurements[0].float_value.value  \
# count                                       1.536000e+03
# mean                                        2.387198e+05
# std                                         1.145788e+05
# min                                         0.000000e+00
# 25%                                         1.931701e+05
# 50%                                         2.191729e+05
# 75%                                         2.396104e+05
# max                                         1.274686e+06
#
#        outcomes[0].analyses["UPLC"].data["product LC area count"].float_value  \
# count                                       1.536000e+03
# mean                                        4.282438e+05
# std                                         9.515332e+05
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.587670e+05
# max                                         6.411983e+06
#
#        outcomes[0].analyses["UPLC"].data["internal_standard LC area count"].float_value  \
# count                                       1.536000e+03
# mean                                        2.387198e+05
# std                                         1.145788e+05
# min                                         0.000000e+00
# 25%                                         1.931701e+05
# 50%                                         2.191729e+05
# 75%                                         2.396104e+05
# max                                         1.274686e+06
#
#        outcomes[0].analyses["UPLC"].data["nucleophile LC area count"].float_value  \
# count                                       1.536000e+03
# mean                                        9.006787e+05
# std                                         1.137724e+06
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.093107e+06
# max                                         5.094170e+06
#
#        outcomes[0].analyses["UPLC"].data["electrophile LC area count"].float_value  \
# count                                       1.536000e+03
# mean                                        8.901066e+05
# std                                         3.836603e+05
# min                                         0.000000e+00
# 25%                                         7.479278e+05
# 50%                                         1.023685e+06
# 75%                                         1.126468e+06
# max                                         2.181530e+06
#
#        inputs["nucleophile"].components[2].amount.moles.value
# count                                               96.0
# mean                                               400.0
# std                                                  0.0
# min                                                400.0
# 25%                                                400.0
# 50%                                                400.0
# 75%                                                400.0
# max                                                400.0

# %%
# Check for NaN values
print(f'number of NaN values: {df.isnull().sum().sum()}')

# Show column counts
df.info()
# Out:
# number of NaN values: 11610
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1536 entries, 0 to 1535
# Data columns (total 45 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   identifiers[0].value                                                              1536 non-null   object
#  1   inputs["base"].components[0].identifiers[0].value                                 1536 non-null   object
#  2   inputs["base"].components[0].identifiers[1].value                                 1536 non-null   object
#  3   inputs["catalyst"].components[0].identifiers[0].value                             1536 non-null   object
#  4   inputs["catalyst"].components[0].identifiers[1].value                             1536 non-null   object
#  5   inputs["nucleophile"].components[0].identifiers[0].value                          1536 non-null   object
#  6   inputs["nucleophile"].components[0].identifiers[1].value                          1536 non-null   object
#  7   outcomes[0].products[0].identifiers[0].value                                      1536 non-null   object
#  8   outcomes[0].products[0].measurements[1].float_value.value                         1536 non-null   float64
#  9   outcomes[0].products[0].measurements[2].analysis_key                              1531 non-null   object
#  10  outcomes[0].products[0].measurements[2].type                                      1531 non-null   object
#  11  outcomes[0].products[0].measurements[2].uses_internal_standard                    1531 non-null   object
#  12  outcomes[0].products[0].measurements[2].is_normalized                             1531 non-null   object
#  13  outcomes[0].products[0].measurements[2].uses_authentic_standard                   1531 non-null   object
#  14  outcomes[0].products[0].measurements[2].float_value.value                         1531 non-null   float64
#  15  outcomes[0].products[1].measurements[1].float_value.value                         1536 non-null   float64
#  16  outcomes[0].products[1].measurements[2].analysis_key                              1531 non-null   object
#  17  outcomes[0].products[1].measurements[2].type                                      1531 non-null   object
#  18  outcomes[0].products[1].measurements[2].uses_internal_standard                    1531 non-null   object
#  19  outcomes[0].products[1].measurements[2].is_normalized                             1531 non-null   object
#  20  outcomes[0].products[1].measurements[2].uses_authentic_standard                   1531 non-null   object
#  21  outcomes[0].products[1].measurements[2].float_value.value                         1531 non-null   float64
#  22  outcomes[0].products[2].identifiers[0].value                                      1536 non-null   object
#  23  outcomes[0].products[2].measurements[1].float_value.value                         1536 non-null   float64
#  24  outcomes[0].products[2].measurements[2].analysis_key                              1531 non-null   object
#  25  outcomes[0].products[2].measurements[2].type                                      1531 non-null   object
#  26  outcomes[0].products[2].measurements[2].uses_internal_standard                    1531 non-null   object
#  27  outcomes[0].products[2].measurements[2].is_normalized                             1531 non-null   object
#  28  outcomes[0].products[2].measurements[2].uses_authentic_standard                   1531 non-null   object
#  29  outcomes[0].products[2].measurements[2].float_value.value                         1531 non-null   float64
#  30  outcomes[0].products[3].measurements[0].float_value.value                         1536 non-null   float64
#  31  outcomes[0].analyses["UPLC"].data["product LC area count"].float_value            1536 non-null   float64
#  32  outcomes[0].analyses["UPLC"].data["internal_standard LC area count"].float_value  1536 non-null   float64
#  33  outcomes[0].analyses["UPLC"].data["nucleophile LC area count"].float_value        1536 non-null   float64
#  34  outcomes[0].analyses["UPLC"].data["electrophile LC area count"].float_value       1536 non-null   float64
#  35  provenance.record_modified[2].time.value                                          1536 non-null   object
#  36  reaction_id                                                                       1536 non-null   object
#  37  inputs["nucleophile"].components[2].identifiers[0].type                           96 non-null     object
#  38  inputs["nucleophile"].components[2].identifiers[0].value                          96 non-null     object
#  39  inputs["nucleophile"].components[2].identifiers[1].type                           96 non-null     object
#  40  inputs["nucleophile"].components[2].identifiers[1].value                          96 non-null     object
#  41  inputs["nucleophile"].components[2].amount.moles.value                            96 non-null     float64
#  42  inputs["nucleophile"].components[2].amount.moles.units                            96 non-null     object
#  43  inputs["nucleophile"].components[2].reaction_role                                 96 non-null     object
#  44  inputs["nucleophile"].components[2].is_limiting                                   96 non-null     object
# dtypes: float64(12), object(33)
# memory usage: 540.1+ KB

# %%
# Create new dataframe containing only columns to be used in modeling
model_cols = ['inputs["catalyst"].components[0].identifiers[0].value',
              'inputs["nucleophile"].components[0].identifiers[0].value',
              'inputs["base"].components[0].identifiers[0].value',
              'outcomes[0].products[0].measurements[0].percentage.value',
             ]
Buitrago_df = df[model_cols]
Buitrago_df

# %% [markdown]
# ### Define pretraining Dataset

# %%
Buitrago_df

# %%
# Get pretraining data
exp_pt = MIT_case1(noise_level=1)
lhs = LHS(exp_pt.domain)
conditions = lhs.suggest_experiments(10)
pt_data = exp_pt.run_experiments((conditions))
pt_data[("task", "METADATA")] = 0
# Use MTBO on a new mechanism
exp = MIT_case2(noise_level=1)
strategy = MTBO(exp.domain,pretraining_data=pt_data, categorical_method="one-hot",task=1)
r = Runner(strategy=strategy, experiment=exp, max_iterations=2)
r.run(progress_bar=False)

# %% [markdown]
# # Optimisation

# %% [markdown]
# ## Learning how the Random strategy works

# %%
#Set up the experiment
exp = baumgartner_cn
exp.reset()
# Instantiate random sampling strategy
strategy = Random(exp.domain)

# Use the runner to run closed loop optimisation
r = Runner(strategy=strategy, experiment=exp, max_iterations=50)
r.run()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='50' class='' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [50/50 00:02<00:00]
#     </div>

# %%
r.experiment.data
# Out:
# NAME inputs["Catalyst"].components[0].identifiers[0].value  \
# TYPE                                                  DATA
# 0                      cycloPd tBuXPhos 4-Chlorotoluene
# 1                        cycloPd AlPhos 4-Chlorotoluene
# 2                         cycloPd EPhos 4-Chlorotoluene
# 3                         cycloPd EPhos 4-Chlorotoluene
# 4                         cycloPd EPhos 4-Chlorotoluene
# 5                        cycloPd AlPhos 4-Chlorotoluene
# 6                        cycloPd AlPhos 4-Chlorotoluene
# 7                      cycloPd tBuXPhos 4-Chlorotoluene
# 8                  cycloPd tBuBrettPhos 4-Chlorotoluene
# 9                  cycloPd tBuBrettPhos 4-Chlorotoluene
# 10                     cycloPd tBuXPhos 4-Chlorotoluene
# 11                     cycloPd tBuXPhos 4-Chlorotoluene
# 12                       cycloPd AlPhos 4-Chlorotoluene
# 13                     cycloPd tBuXPhos 4-Chlorotoluene
# 14                     cycloPd tBuXPhos 4-Chlorotoluene
# 15                     cycloPd tBuXPhos 4-Chlorotoluene
# 16                        cycloPd EPhos 4-Chlorotoluene
# 17                       cycloPd AlPhos 4-Chlorotoluene
# 18                       cycloPd AlPhos 4-Chlorotoluene
# 19                       cycloPd AlPhos 4-Chlorotoluene
# 20                 cycloPd tBuBrettPhos 4-Chlorotoluene
# 21                     cycloPd tBuXPhos 4-Chlorotoluene
# 22                 cycloPd tBuBrettPhos 4-Chlorotoluene
# 23                       cycloPd AlPhos 4-Chlorotoluene
# 24                       cycloPd AlPhos 4-Chlorotoluene
# 25                        cycloPd EPhos 4-Chlorotoluene
# 26                     cycloPd tBuXPhos 4-Chlorotoluene
# 27                        cycloPd EPhos 4-Chlorotoluene
# 28                        cycloPd EPhos 4-Chlorotoluene
# 29                 cycloPd tBuBrettPhos 4-Chlorotoluene
# 30                       cycloPd AlPhos 4-Chlorotoluene
# 31                     cycloPd tBuXPhos 4-Chlorotoluene
# 32                     cycloPd tBuXPhos 4-Chlorotoluene
# 33                 cycloPd tBuBrettPhos 4-Chlorotoluene
# 34                       cycloPd AlPhos 4-Chlorotoluene
# 35                        cycloPd EPhos 4-Chlorotoluene
# 36                        cycloPd EPhos 4-Chlorotoluene
# 37                 cycloPd tBuBrettPhos 4-Chlorotoluene
# 38                        cycloPd EPhos 4-Chlorotoluene
# 39                        cycloPd EPhos 4-Chlorotoluene
# 40                        cycloPd EPhos 4-Chlorotoluene
# 41                 cycloPd tBuBrettPhos 4-Chlorotoluene
# 42                     cycloPd tBuXPhos 4-Chlorotoluene
# 43                        cycloPd EPhos 4-Chlorotoluene
# 44                 cycloPd tBuBrettPhos 4-Chlorotoluene
# 45                       cycloPd AlPhos 4-Chlorotoluene
# 46                     cycloPd tBuXPhos 4-Chlorotoluene
# 47                        cycloPd EPhos 4-Chlorotoluene
# 48                        cycloPd EPhos 4-Chlorotoluene
# 49                       cycloPd AlPhos 4-Chlorotoluene
#
# NAME inputs["Nucleophile"].components[0].identifiers[0].value  \
# TYPE                                                     DATA
# 0                                               Aniline
# 1                                               Aniline
# 2                                        Phenethylamine
# 3                                               Aniline
# 4                                               Aniline
# 5                                               Aniline
# 6                                             Benzamide
# 7                                            Morpholine
# 8                                             Benzamide
# 9                                            Morpholine
# 10                                       Phenethylamine
# 11                                              Aniline
# 12                                       Phenethylamine
# 13                                            Benzamide
# 14                                       Phenethylamine
# 15                                            Benzamide
# 16                                       Phenethylamine
# 17                                           Morpholine
# 18                                           Morpholine
# 19                                           Morpholine
# 20                                            Benzamide
# 21                                              Aniline
# 22                                              Aniline
# 23                                            Benzamide
# 24                                           Morpholine
# 25                                            Benzamide
# 26                                       Phenethylamine
# 27                                       Phenethylamine
# 28                                              Aniline
# 29                                              Aniline
# 30                                              Aniline
# 31                                              Aniline
# 32                                              Aniline
# 33                                           Morpholine
# 34                                            Benzamide
# 35                                            Benzamide
# 36                                            Benzamide
# 37                                           Morpholine
# 38                                       Phenethylamine
# 39                                            Benzamide
# 40                                              Aniline
# 41                                           Morpholine
# 42                                              Aniline
# 43                                              Aniline
# 44                                       Phenethylamine
# 45                                            Benzamide
# 46                                            Benzamide
# 47                                            Benzamide
# 48                                       Phenethylamine
# 49                                              Aniline
#
# NAME inputs["Base"].components[0].identifiers[0].value  \
# TYPE                                              DATA
# 0                                                 BTTP
# 1                                                 BTTP
# 2                                                  TEA
# 3                                                 BTMG
# 4                                                  DBU
# 5                                                 MTBD
# 6                                                 MTBD
# 7                                                 MTBD
# 8                                                 BTTP
# 9                                                 BTMG
# 10                                                BTTP
# 11                                                BTMG
# 12                                                P2Et
# 13                                                BTMG
# 14                                                BTTP
# 15                                                 TMG
# 16                                                MTBD
# 17                                       Triethylamine
# 18                                                P2Et
# 19                                                 TEA
# 20                                                BTMG
# 21                                                MTBD
# 22                                                BTTP
# 23                                                MTBD
# 24                                                 TMG
# 25                                       Triethylamine
# 26                                                P2Et
# 27                                                 TEA
# 28                                                BTTP
# 29                                                 TMG
# 30                                                 DBU
# 31                                                BTTP
# 32                                                 TEA
# 33                                                 DBU
# 34                                                BTMG
# 35                                                 TMG
# 36                                                 DBU
# 37                                                 DBU
# 38                                                 TEA
# 39                                                MTBD
# 40                                                MTBD
# 41                                                BTTP
# 42                                       Triethylamine
# 43                                                BTTP
# 44                                                BTTP
# 45                                                MTBD
# 46                                                 TMG
# 47                                                 DBU
# 48                                                MTBD
# 49                                                 TEA
#
# NAME inputs["Solvent"].components[0].identifiers[0].value  \
# TYPE                                                 DATA
# 0                                                  DMSO
# 1                                               2-MeTHF
# 2                                                  DMSO
# 3                                                  DMSO
# 4                                               2-MeTHF
# 5                                                  DMSO
# 6                                                  DMSO
# 7                                               2-MeTHF
# 8                                               2-MeTHF
# 9                                               2-MeTHF
# 10                                              2-MeTHF
# 11                                                 DMSO
# 12                                                 DMSO
# 13                                                 DMSO
# 14                                                 DMSO
# 15                                              2-MeTHF
# 16                                              2-MeTHF
# 17                                              2-MeTHF
# 18                                                 DMSO
# 19                                                 DMSO
# 20                                              2-MeTHF
# 21                                                 DMSO
# 22                                                 DMSO
# 23                                              2-MeTHF
# 24                                              2-MeTHF
# 25                                              2-MeTHF
# 26                                              2-MeTHF
# 27                                                 DMSO
# 28                                                 DMSO
# 29                                              2-MeTHF
# 30                                              2-MeTHF
# 31                                              2-MeTHF
# 32                                              2-MeTHF
# 33                                                 DMSO
# 34                                              2-MeTHF
# 35                                                 DMSO
# 36                                                 DMSO
# 37                                                 DMSO
# 38                                              2-MeTHF
# 39                                              2-MeTHF
# 40                                              2-MeTHF
# 41                                                 DMSO
# 42                                              2-MeTHF
# 43                                              2-MeTHF
# 44                                              2-MeTHF
# 45                                              2-MeTHF
# 46                                              2-MeTHF
# 47                                                 DMSO
# 48                                              2-MeTHF
# 49                                                 DMSO
#
# NAME outcomes[0].reaction_time.value conditions.temperature.setpoint.value  \
# TYPE                            DATA                                  DATA
# 0                        5893.391328                             39.037304
# 1                        1782.167439                             78.857304
# 2                        3211.940753                             46.918225
# 3                        4705.788330                             88.979451
# 4                        2252.655043                             90.303206
# 5                        4099.706201                             92.286932
# 6                        5952.445800                             33.746432
# 7                        5055.771261                             62.466915
# 8                        4006.385207                             80.285205
# 9                        2872.073481                             50.796707
# 10                       5856.226491                             57.268161
# 11                        710.533905                             54.428877
# 12                       3418.092632                             93.892094
# 13                       5317.780692                             71.194342
# 14                       1099.845103                             94.925298
# 15                       1773.757523                             61.614795
# 16                        153.137350                             30.178655
# 17                       4164.649550                             65.407853
# 18                       5017.900830                             78.030343
# 19                       5682.634737                             99.056370
# 20                       4645.677036                             55.785957
# 21                       3458.500135                             63.559085
# 22                       2186.353456                             97.889199
# 23                       2225.964870                            108.734528
# 24                        316.560194                             69.169805
# 25                       3452.555640                            109.076843
# 26                       4555.772117                             85.533704
# 27                       5993.553924                             94.760312
# 28                       1009.711201                             84.319994
# 29                       1299.328963                             33.335626
# 30                       1067.860313                             66.838899
# 31                       4743.780497                             36.325331
# 32                       2206.913510                             44.121466
# 33                       2142.622039                             53.956265
# 34                       2465.504936                             42.647085
# 35                       3311.074777                             93.838971
# 36                       3854.594066                             66.397200
# 37                       5204.593104                             97.595572
# 38                       3719.346763                             53.048117
# 39                        991.059792                             58.615819
# 40                       3189.718789                             67.429832
# 41                       3469.402062                             82.593815
# 42                       5182.309314                             74.915904
# 43                       2075.967959                             92.255868
# 44                       5558.619389                             98.306162
# 45                        818.070788                             69.931835
# 46                        624.900097                             66.474000
# 47                       3025.389623                            103.998210
# 48                       1522.710161                             43.010588
# 49                       1424.462823                             97.670725
#
# NAME outcomes[0].products[0].measurements[0].percentage.value computation_t  \
# TYPE                                                     DATA      METADATA
# 0                                             51.531013                 0.0
# 1                                            105.000000            0.011679
# 2                                              0.000000            0.010716
# 3                                             48.286976            0.011475
# 4                                             28.887344            0.009549
# 5                                             92.656807            0.008956
# 6                                             43.536140            0.009752
# 7                                              0.000000            0.009342
# 8                                             42.910522            0.007398
# 9                                             15.564214            0.009582
# 10                                            26.075298            0.007516
# 11                                            69.920853            0.007046
# 12                                            71.644951            0.006898
# 13                                            16.368015            0.008054
# 14                                            77.769302            0.007541
# 15                                             6.074955            0.008037
# 16                                             0.000000            0.006763
# 17                                            17.714157            0.007921
# 18                                            22.713797            0.008037
# 19                                             0.000000            0.007187
# 20                                            33.440842            0.006267
# 21                                            43.577175            0.008324
# 22                                           101.105507            0.007049
# 23                                            77.788742            0.006738
# 24                                             0.000000            0.006368
# 25                                             5.344418            0.008683
# 26                                             9.002069            0.007217
# 27                                             0.000000            0.006541
# 28                                            80.995575            0.009447
# 29                                            17.585217            0.008539
# 30                                            90.020432            0.006698
# 31                                            63.544983            0.006547
# 32                                             8.385191            0.006338
# 33                                             1.337506            0.008155
# 34                                            82.087540             0.00743
# 35                                             0.274984            0.008515
# 36                                             0.000000            0.011322
# 37                                             0.000000            0.008719
# 38                                             0.000000            0.007437
# 39                                            13.194666            0.007229
# 40                                            33.271721             0.00629
# 41                                            14.412570            0.009144
# 42                                            26.020361            0.008068
# 43                                            73.289963             0.00707
# 44                                            35.805199            0.007131
# 45                                            68.408821            0.008839
# 46                                             1.205643             0.00752
# 47                                             0.000000            0.007059
# 48                                             3.555774            0.006516
# 49                                            43.003334             0.00862
#
# NAME experiment_t strategy
# TYPE     METADATA METADATA
# 0        0.031588   Random
# 1        0.033523   Random
# 2        0.028566   Random
# 3        0.027955   Random
# 4        0.027082   Random
# 5        0.024352   Random
# 6        0.028418   Random
# 7        0.028177   Random
# 8        0.025644   Random
# 9        0.027209   Random
# 10       0.024215   Random
# 11       0.022376   Random
# 12       0.021636   Random
# 13       0.025699   Random
# 14       0.023542   Random
# 15       0.022122   Random
# 16       0.022931   Random
# 17       0.025636   Random
# 18       0.023061   Random
# 19       0.022342   Random
# 20       0.021946   Random
# 21       0.025159   Random
# 22       0.022933   Random
# 23        0.02198   Random
# 24       0.024615   Random
# 25       0.025984   Random
# 26       0.023743   Random
# 27       0.023077   Random
# 28       0.023998   Random
# 29       0.025389   Random
# 30       0.024823   Random
# 31       0.022386   Random
# 32       0.021487   Random
# 33       0.027976   Random
# 34       0.027926   Random
# 35       0.029949   Random
# 36       0.025936   Random
# 37       0.025914   Random
# 38       0.025453   Random
# 39        0.02319   Random
# 40       0.021935   Random
# 41       0.035336   Random
# 42       0.024123   Random
# 43       0.023897   Random
# 44       0.022874   Random
# 45       0.025021   Random
# 46       0.024804   Random
# 47       0.022839   Random
# 48       0.022565   Random
# 49       0.025901   Random

# %%
random_yield = r.experiment.data['outcomes[0].products[0].measurements[0].percentage.value']
plt.plot(random_yield)

# %%
random_yield_max = []
for i in range(len(random_yield)):
    if i == 0:
        j = random_yield[i]
    else:
        j = max(random_yield[i],random_yield_max[i-1])
    random_yield_max+=[j]

# %%
plt.plot(random_yield_max)

# %%
type(exp.domain['inputs["Base"].components[0].identifiers[0].value'].levels[0])

# %%
exp.domain.num_continuous_dimensions()

# %%
#Set up the experiment
exp.reset()
exp = CN_benchmark

# Instantiate sampling strategy
strategy = SOBO(exp.domain)

# Use the runner to run closed loop optimisation
r = Runner(strategy=strategy, experiment=exp, max_iterations=50)
r.run()

# %%
SOBO_yield = r.experiment.data['outcomes[0].products[0].measurements[0].percentage.value']
plt.plot(SOBO_yield)

# %%
SOBO_yield_max = []
for i in range(len(SOBO_yield)):
    if i == 0:
        j = SOBO_yield[i]
    else:
        j = max(SOBO_yield[i],SOBO_yield_max[i-1])
    SOBO_yield_max+=[j]
plt.plot(random_yield_max)

# %% [markdown]
# ## Run strategies
# - Random strategy
# - SOBO: Single Objective Bayesian Optimisation
# - STBO: Single Task Bayesian Optimisation
# - MTBO: Multitask Bayesian Optimisation

# %%
def run_random(exp, max_iterations=10, random_state=np.random.RandomState(3)):
    exp.reset()
    strategy = Random(exp.domain, 
                    random_state=random_state)
    r = summit.Runner(strategy=strategy, 
                      experiment=exp, 
                      max_iterations=max_iterations)
    r.run()
    return r

def run_sobo(exp, max_iterations=10, categorical_method="one-hot"):
    exp.reset()
    strategy = SOBO(exp.domain, 
                    categorical_method=categorical_method)
    r = summit.Runner(strategy=strategy, 
                      experiment=exp, 
                      max_iterations=max_iterations)
    r.run()
    return r

def run_mtbo(exp, pt_data, max_iterations=10, task=1):
    strategy = MTBO(exp.domain, 
                    pretraining_data=pt_data,
                    categorical_method="one-hot", 
                    task=task)
    r = summit.Runner(strategy=strategy,
                      experiment=exp, 
                      max_iterations=max_iterations)
    r.run()
    return r

def make_average_plot(results: [summit.Runner], ax, label=None, color=None):
    objective = results[0].experiment.domain.output_variables[0].name
    yields = [r.experiment.data[objective] for r in results]
    yields = np.array(yields)
    mean_yield = np.mean(yields, axis=0)
    std_yield = np.std(yields, axis=0)
    x = np.arange(0, len(mean_yield), 1).astype(int)
    ax.plot(x, mean_yield, label=label, linewidth=2, color=color)
    ax.fill_between(x, mean_yield-std_yield, mean_yield+std_yield, alpha=0.1, color=color)

def make_comparison_plot(*args):
    fig, ax = plt.subplots(1)
    for arg in args:
        make_average_plot(arg['results'], ax, label=arg["label"], color=arg["color"])
    fontdict = fontdict={"size":12}
    ax.legend(loc = "lower right", prop=fontdict)
    ax.set_xlim(0,20)
    ax.set_xticks(np.arange(0, 20, 2).astype(int))
    ax.set_ylabel('Yield', fontdict=fontdict)
    ax.set_xlabel('Reactions', fontdict=fontdict)
    ax.tick_params(direction='in')
    return fig, ax

# %%
# Load benchmark
baumgartner_cn = ExperimentalEmulator.load(model_name="baumgartner_cn", save_dir="../data/baumgartner_C-N/baumgartner_C-N_emulator")

# %%
#Set up the experiment
exp = baumgartner_cn
exp.reset()
# Instantiate random sampling strategy
strategy = Random(exp.domain)

# Use the runner to run closed loop optimisation
r = Runner(strategy=strategy, experiment=exp, max_iterations=50)
r.run()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='50' class='' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [50/50 00:02<00:00]
#     </div>

# %%
N_REPEATS = 10
MAX_ITERATIONS = 20

# %%
#Random
for i in range(N_REPEATS):
    print(f"Repeat {i}")
    exp = baumgartner_cn
    result = run_random(exp, max_iterations=MAX_ITERATIONS)
    result.save(f"../data/baumgartner_C-N/results/random_{i}.json")
    clear_output(wait=True)
# Out:
# Repeat 9
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20/20 00:00<00:00]
#     </div>

# %%
#Single-Objective Bayesian Optimization
for i in range(N_REPEATS):
    print(f"Repeat {i}")
    exp = baumgartner_cn
    result = run_sobo(exp, max_iterations=MAX_ITERATIONS)
    result.save(f"../data/baumgartner_C-N/results/SOBO_{i}.json")
    clear_output(wait=True)
# Out:
# Repeat 9
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20/20 00:05<00:00]
#     </div>

# %% [markdown]
# ## multitask BO

# %%
#4 nucleophiles choose 2
# Pretrain with data on nucleophile A to predict best conditions for nucleophile B

# %%
#load in the data
pb = '../data/baumgartner_C-N/baumgartner_C-N.pb'
# Load Dataset message
data = message_helpers.load_message(pb, dataset_pb2.Dataset)
# Ensure dataset validates
valid_output = validations.validate_message(data)
# Convert dataset to pandas dataframe
df = message_helpers.messages_to_dataframe(data.reactions, 
                                           drop_constant_columns=True)

# Create new dataframe containing only columns to be used in modeling
model_cols = ['inputs["Catalyst"].components[0].identifiers[0].value',
              'inputs["Base"].components[0].identifiers[0].value',
              'inputs["Solvent"].components[0].identifiers[0].value',
              'inputs["Nucleophile"].components[0].identifiers[0].value',
              'outcomes[0].reaction_time.value',
              'conditions.temperature.setpoint.value',
              'outcomes[0].products[0].measurements[0].percentage.value',
             ]
df = df[model_cols]
df
# Out:
#     inputs["Catalyst"].components[0].identifiers[0].value  \
# 0                        cycloPd EPhos 4-Chlorotoluene
# 1                        cycloPd EPhos 4-Chlorotoluene
# 2                        cycloPd EPhos 4-Chlorotoluene
# 3                        cycloPd EPhos 4-Chlorotoluene
# 4                        cycloPd EPhos 4-Chlorotoluene
# ..                                                 ...
# 369               cycloPd tBuBrettPhos 4-Chlorotoluene
# 370               cycloPd tBuBrettPhos 4-Chlorotoluene
# 371               cycloPd tBuBrettPhos 4-Chlorotoluene
# 372               cycloPd tBuBrettPhos 4-Chlorotoluene
# 373               cycloPd tBuBrettPhos 4-Chlorotoluene
#
#     inputs["Base"].components[0].identifiers[0].value  \
# 0                                                BTMG
# 1                                                 DBU
# 2                                                 DBU
# 3                                                 TEA
# 4                                                BTMG
# ..                                                ...
# 369                                               TEA
# 370                                              MTBD
# 371                                               DBU
# 372                                              MTBD
# 373                                               DBU
#
#     inputs["Solvent"].components[0].identifiers[0].value  \
# 0                                              2-MeTHF
# 1                                              2-MeTHF
# 2                                              2-MeTHF
# 3                                              2-MeTHF
# 4                                              2-MeTHF
# ..                                                 ...
# 369                                            2-MeTHF
# 370                                            2-MeTHF
# 371                                            2-MeTHF
# 372                                            2-MeTHF
# 373                                            2-MeTHF
#
#     inputs["Nucleophile"].components[0].identifiers[0].value  \
# 0                                              Aniline
# 1                                              Aniline
# 2                                              Aniline
# 3                                              Aniline
# 4                                              Aniline
# ..                                                 ...
# 369                                         Morpholine
# 370                                         Morpholine
# 371                                         Morpholine
# 372                                         Morpholine
# 373                                         Morpholine
#
#      outcomes[0].reaction_time.value  conditions.temperature.setpoint.value  \
# 0                        1324.577759                                   65.0
# 1                         374.843445                                   65.0
# 2                        1296.335205                                  100.0
# 3                         595.096008                                   30.0
# 4                        1346.552979                                   65.0
# ..                               ...                                    ...
# 369                        73.882225                                   30.0
# 370                        76.790390                                   30.0
# 371                      1294.963013                                   30.0
# 372                        81.582664                                  100.0
# 373                        97.631584                                  100.0
#
#      outcomes[0].products[0].measurements[0].percentage.value
# 0                                            61.873035
# 1                                             1.446805
# 2                                            21.348686
# 3                                             0.274913
# 4                                            54.948227
# ..                                                 ...
# 369                                           0.100000
# 370                                           0.100000
# 371                                           5.087716
# 372                                           0.100000
# 373                                           4.671374
#
# [374 rows x 7 columns]

# %%
# shuffle df
df_shuffle = df.sample(frac=1)
#convert to summit dataset
baumgartner_cn_ds = DataSet.from_df(df_shuffle)

# %%
#Multi-Task Bayesian Optimization
for i in range(N_REPEATS):
    print(f"Repeat {i}")
    exp = baumgartner_cn
    result = run_mtbo(exp, baumgartner_cn_ds, max_iterations=MAX_ITERATIONS)
    result.save(f"../data/baumgartner_C-N/results/MTBO_{i}.json")
    clear_output(wait=True)
# Out:
# Repeat 0
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.00% [1/20 00:00<00:01]
#     </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e1c575c3867e> in <module>
#       3     print(f"Repeat {i}")
#       4     exp = baumgartner_cn
# ----> 5     result = run_mtbo(exp, baumgartner_cn_ds, max_iterations=MAX_ITERATIONS)
#       6     result.save(f"../data/baumgartner_C-N/results/MTBO_{i}.json")
#       7     clear_output(wait=True)
#
# <ipython-input-6-e1d1e9264019> in run_mtbo(exp, pt_data, max_iterations, task)
#      27                       experiment=exp,
#      28                       max_iterations=max_iterations)
# ---> 29     r.run()
#      30     return r
#      31
#
# ~/Library/Caches/pypoetry/virtualenvs/multitask-P_6kt6PW-py3.7/lib/python3.7/site-packages/summit/run.py in run(self, **kwargs)
#     163             else:
#     164                 next_experiments = self.strategy.suggest_experiments(
# --> 165                     num_experiments=self.batch_size, prev_res=prev_res
#     166                 )
#     167             prev_res = self.experiment.run_experiments(next_experiments)
#
# ~/Library/Caches/pypoetry/virtualenvs/multitask-P_6kt6PW-py3.7/lib/python3.7/site-packages/summit/strategies/multitask.py in suggest_experiments(self, num_experiments, prev_res, **kwargs)
#     156         if "task" not in self.pretraining_data.metadata_columns:
#     157             raise ValueError(
# --> 158                 """The pretraining data must have a METADATA column called "task" with the task number."""
#     159             )
#     160         data = self.all_experiments.append(self.pretraining_data)
#
# ValueError: The pretraining data must have a METADATA column called "task" with the task number.

# %% [markdown]
# ## Plot results

# %%
random_results = [summit.Runner.load(f"../data/baumgartner_C-N/results/random_{i}.json") for i in range(10)]
sobo_results = [summit.Runner.load(f"../data/baumgartner_C-N/results/SOBO_{i}.json") for i in range(10)]
#mtbo_results_lists = [[summit.Runner.load(f"data/kinetics_similar/mtbo_case1-2_noise_{n}-pre-train_repeat_{i}.json") 
#                      for i in range(10)]
#                      for n in n_aux]
#

fig, ax = make_comparison_plot(
    dict(results=random_results, label="Random", color = 'blue'),
    dict(results=sobo_results, label="SOBO", color = 'orange'),
#     dict(results=mtbo_results_lists[0],label="MTBO, n=5"),
#    dict(results=mtbo_results_lists[1],label="MTBO, n=10"),
#    dict(results=mtbo_results_lists[2],label="MTBO, n=50")
)
#fig.savefig("figures/stbo_mtbo_kinetics_case1-2_noise_comparison.png", bbox_inches='tight', dpi=300)

# %% [markdown]
# # Implementing Gaussian process by hand

# %%
# Define the exponentiated quadratic 
def exponentiated_quadratic(xa, xb):
    """Exponentiated quadratic  with σ=1"""
    # L2 distance (Squared Euclidian)
    sq_norm = -0.5 * scipy.spatial.distance.cdist(xa, xb, 'sqeuclidean')
    return np.exp(sq_norm)

# %%
# Sample from the Gaussian process distribution
nb_of_samples = 41  # Number of points in each function
number_of_functions = 5  # Number of functions to sample
# Independent variable samples
X = np.expand_dims(np.linspace(-4, 4, nb_of_samples), 1)
Σ = exponentiated_quadratic(X, X)  # Kernel of data points

# Draw samples from the prior at our data points.
# Assume a mean of 0 for simplicity
ys = np.random.multivariate_normal(
    mean=np.zeros(nb_of_samples), cov=Σ, 
    size=number_of_functions)

# %%
ys[0]
# Out:
# array([ 0.04368182, -0.14249363, -0.310708  , -0.44146671, -0.52274515,
#        -0.55182677, -0.53602496, -0.49122981, -0.43791455, -0.39569348,
#        -0.37840926, -0.39134275, -0.43103451, -0.48736538, -0.54727721,
#        -0.5993348 , -0.63776429, -0.66405242, -0.68469408, -0.70571105,
#        -0.72702275, -0.74051341, -0.73347045, -0.69516263, -0.62175074,
#        -0.51586326, -0.3814108 , -0.21818411, -0.02114957,  0.21429204,
#         0.48458164,  0.77343432,  1.05399579,  1.29679846,  1.47904967,
#         1.59047705,  1.63353467,  1.61900751,  1.55988738,  1.46632439,
#         1.34331535])

# %%
# Plot the sampled functions
plt.figure(figsize=(6, 4))
for i in range(number_of_functions):
    plt.plot(X, ys[i], linestyle='-', marker='o', markersize=3)
plt.xlabel('$x$', fontsize=13)
plt.ylabel('$y = f(x)$', fontsize=13)
plt.title((
    '5 different function realizations at 41 points\n'
    'sampled from a Gaussian process with exponentiated quadratic kernel'))
plt.xlim([-4, 4])
plt.show()
#

# %%
mean = [0, 0, 0]
cov = [[1, 0, 0], 
       [0, 1, 0],
       [0, 0, 1]]  # diagonal covariance

# %%
x, y, z = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()
